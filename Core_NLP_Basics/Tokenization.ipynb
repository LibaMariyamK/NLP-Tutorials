# %% [markdown]
# # 1. What is Tokenization?

# %% [markdown]
# **Tokenization** means **breaking text into smaller pieces** called **tokens**.
# Tokens can be:
#
# * **Words**
#
#   * “NLP is fun” → `["NLP", "is", "fun"]`
# * **Sentences**
#
#   * “NLP is fun. I love it.” → `["NLP is fun.", "I love it."]`
# * **Subwords / pieces** (used in modern LLMs like BERT/GPT)
#
#   * “playing” → `["play", "##ing"]`
#
# **Why do we tokenize?**
# Because machines cannot understand raw text. Tokenization converts text into parts that ML models can process.

# %% [markdown]
# # 2. Tokenization with NLTK

# %% [markdown]
# ### 🔽 Install NLTK

# %%
pip install nltk

# %% [markdown]
# ### 🔽 Download tokenizer models

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# ### ⭐ Word Tokenization

# %%
from nltk.tokenize import word_tokenize

text = "NLP is fun. I love learning it!"
tokens = word_tokenize(text)
print(tokens)
# Out:
# ['NLP', 'is', 'fun', '.', 'I', 'love', 'learning', 'it', '!']

# %% [markdown]
# 👉 Notice - punctuation also appears as tokens.

# %% [markdown]
# ### ⭐ Sentence Tokenization

# %%
from nltk.tokenize import sent_tokenize

text = "NLP is fun. I love learning it!"
sentences = sent_tokenize(text)
print(sentences)
# Out:
# ['NLP is fun.', 'I love learning it!']

# %% [markdown]
# # 3. Tokenization with spaCy

# %% [markdown]
# ### 🔽 Install spaCy

# %%
pip install spacy

# %% [markdown]
# ### 🔽 Download & Load English model

# %%
python -m spacy download en_core_web_sm

# %%
import spacy                      

nlp = spacy.load("en_core_web_sm")  
# Load the English model used for tokenization, POS, NER, etc.

# %% [markdown]
# **`en_core_web_sm`**
#
# It is the **English language model** that spaCy provides.
#
# * **en** → English language
# * **core** → general-purpose model
# * **web** → trained on web text
# * **sm** → small size model

# %% [markdown]
# ### ⭐ Word Tokenization

# %%
text = "NLP is fun. I love learning it!"  

doc = nlp(text)  
# Pass the text to spaCy’s pipeline so it becomes a processed Doc object

word_tokens = [token.text for token in doc]  
# Extract each token (word, punctuation, etc.) from the Doc object

print(word_tokens)
# Out:
# ['NLP', 'is', 'fun', '.', 'I', 'love', 'learning', 'it', '!']

# %% [markdown]
# 👉 Similar to NLTK but spaCy is faster and more accurate.

# %% [markdown]
# ### ⭐ Sentence Tokenization

# %%
sentence_tokens = [sent.text for sent in doc.sents]
print(sentence_tokens)
# Out:
# ['NLP is fun.', 'I love learning it!']

# %% [markdown]
# spaCy automatically splits sentences using its built-in parser.

# %% [markdown]
# ## Summary
#
# | Feature           | NLTK   | spaCy                        |
# | ----------------- | ------ | ---------------------------- |
# | Speed             | Slow   | Very fast                    |
# | Beginner friendly | ✔✔✔    | ✔✔                           |
# | Word tokens       | ✔      | ✔                            |
# | Sentence tokens   | ✔      | ✔                            |
# | Industry use      | Medium | High                         |
# | Extra features    | Basic  | NER, POS, dependency parsing |
